# %%
from bs4 import BeautifulSoup
from selenium import webdriver

url = 'https://www.fairprice.com.sg/search?query=babyfood'


driver = webdriver.Chrome(executable_path='./chromedriver')
driver.get(url)

soup = BeautifulSoup(driver.page_source, features='html.parser')
driver.quit()

print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta content="#1557BF" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoBlack.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoBold.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoRegular.woff2" rel="preload"/>
#   <link href="https://website-api.omni.fairprice.com.sg" rel="preconnect"/>
#   <link href="https://media.nedigital.sg" rel="preconnect"/>
#   <link href="https://fairprice.api.useinsider.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://website-api.omni.fairprice.com.sg" rel="dns-prefetch"/>
# ...

# %%
product=soup.find("div",{"data-testid":"product"})
print(product.prettify())
# Out:
# <div class="sc-1plwklf-1 jwePBs" data-testid="product">
#  <div class="sc-1plwklf-18 fKgUOn">
#   <span borderstyle="single" class="sc-1bsd7ul-0 sc-1plwklf-17 jPEOCG" color="#ffffff" weight="bold">
#    Offer
#   </span>
#  </div>
#  <div class="sc-1plwklf-11 ksbNnN">
#   <div class="sc-1plwklf-4 nUisu" data-testid="recommended-product-image">
#    <img alt="Gerber Organic Baby Cereal - Rice" class="sc-1plwklf-19 kALgJe" src="https://media.nedigital.sg/fairprice/fpol/media/images/product/L/13129621_L1.jpg?q=60"/>
#   </div>
#  </div>
#  <div class="sc-1plwklf-7 ehsEQD">
#   <div class="sc-1plwklf-10 giSqOB">
#    <div class="sc-1plwklf-9 heTVFR">
#     <span class="sc-1bsd7ul-0 SygsP" weight="black">
#      <span class="sc-1bsd7ul-0 iHZPfe">
#       $10.90
#      </span>
#     </span>
#    </div>
#    <div class="sc-1plwklf-9 heTVFR">
#     <button class="sc-1plwklf-8 gJmRIw" data-testid="shortlistProduct">
#      <svg color="#1557bf" height="24" viewbox="0 0 24 24" width="24">
# ...

# %%
price=product.find("span",class_="sc-1bsd7ul-0 iHZPfe")
print(price.text)
name=product.find("span",class_="sc-1bsd7ul-0 bWyUDf")
print(name.text)
# Out:
# $10.90
# Gerber Organic Baby Cereal - Rice

# %% [markdown]
# ### Save CSV File

# %%
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('fairprice.csv', 'w')#define csv_file

csv_writer = csv.writer(csv_file) #define csv_writer
csv_writer.writerow(['name', 'price'])

for product in soup.find_all("div",{"data-testid":"product"}):
    price=product.find("span",class_="sc-1bsd7ul-0 iHZPfe")
    price=price.text
    name=product.find("span",class_="sc-1bsd7ul-0 bWyUDf")
    name=name.text

    csv_writer.writerow([name,price])

csv_file.close()

# %% [markdown]
# ### How to get infinite scroll (Theory)

# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromrdriver = "/home/chromedriver"
os.environ["webdriver.chrome.driver"] = chromrdriver
driver = webdriver.Chrome(chromrdriver)
driver.get("https://medium.com/search?q=data%20science")

ScrollNumber = 50
for i in range(1,ScrollNumber):
    driver.execute_script("window.scrollTo(1,50000)")
    time.sleep(5)

file = open('DS.html', 'w')
file.write(driver.page_source)
file.close()

driver.close()

# %% [markdown]
# ### infinite scroll (Practical)

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

url = 'https://www.fairprice.com.sg/search?query=babyfood'


driver = webdriver.Chrome(executable_path='./chromedriver')
driver.get(url)

ScrollNumber = 50
for i in range(1,ScrollNumber):
    driver.execute_script("window.scrollTo(1,50000)")
    
time.sleep(5)
file = open('DS.html', 'w')
file.write(driver.page_source)
file.close()

soup = BeautifulSoup(driver.page_source, features='html.parser')
driver.quit()

print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta content="#1557BF" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoBlack.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoBold.woff2" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="/static/fonts/latoRegular.woff2" rel="preload"/>
#   <link href="https://website-api.omni.fairprice.com.sg" rel="preconnect"/>
#   <link href="https://media.nedigital.sg" rel="preconnect"/>
#   <link href="https://fairprice.api.useinsider.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://connect.facebook.net" rel="preconnect"/>
#   <link href="https://website-api.omni.fairprice.com.sg" rel="dns-prefetch"/>
# ...

# %%
from bs4 import BeautifulSoup
import requests
import csv

csv_file = open('fairprice_2.csv', 'w')#define csv_file

csv_writer = csv.writer(csv_file) #define csv_writer
csv_writer.writerow(['name', 'price'])

for product in soup.find_all("div",{"data-testid":"product"}):
    price=product.find("span",class_="sc-1bsd7ul-0 iHZPfe")
    price=price.text
    name=product.find("span",class_="sc-1bsd7ul-0 bWyUDf")
    name=name.text

    csv_writer.writerow([name,price])

csv_file.close()
